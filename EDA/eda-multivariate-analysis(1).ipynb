# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('indian_properties_cleaned_v1.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  experion the heartsong  sector 108   1.68          8387.0
# 1          flat         emaar digihomes   sector 62   2.45         16000.0
# 2         house             independent   sector 43   5.50          2716.0
# 3         house             independent   sector 38   3.90         21242.0
# 4         house             independent   sector 27   4.25         31481.0
#
#       area                                       areaWithType  bedRoom  \
# 0   2003.0  Super Built up area 2003(186.08 sq.m.)Built Up...        3
# 1   1531.0  Built Up area: 1200 (111.48 sq.m.)Carpet area:...        2
# 2  20250.0  Plot area 215(179.77 sq.m.)Built Up area: 2850...        8
# 3   1836.0                        Plot area 204(170.57 sq.m.)        6
# 4   1350.0  Plot area 163(136.29 sq.m.)Built Up area: 161 ...        5
#
#    bathroom balcony                             additionalRoom  floorNum  \
# 0         3      3+                    servant room,study room       4.0
# 1         2       2                                 study room       7.0
# 2         7      3+  pooja room,study room,servant room,others       3.0
# 3         6      3+         pooja room,study room,servant room       3.0
# 4         5      3+                    pooja room,servant room       3.0
#
#        facing     agePossession  \
# 0        East   1 to 5 Year Old
# 1  North-East   0 to 1 Year Old
# 2        East  5 to 10 Year Old
# 3  North-East  5 to 10 Year Old
# 4        East   1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Galleria 108 Mall', 'Dwarka Expressway', 'Ce...
# 1  ['Sector 55-56 Metro Station', 'Omaxe Gurgaon ...
# 2  ['Huda city centre metro station', 'New Life C...
# 3  ['Rajiv Chowk Mosque', 'Icici bank ATM', 'Stat...
# 4  ['Dlf phase 1 metro station', 'Sector 42-43 me...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '6 Fan', '1 Exhaust Fan', '1 Ge...
# 1  ['1 Water Purifier', '2 Fan', '1 Fridge', '1 E...
# 2  ['8 Wardrobe', '10 Fan', '1 Exhaust Fan', '10 ...
# 3                                                NaN
# 4  ['10 Wardrobe', '1 Water Purifier', '7 Fan', '...
#
#                                             features
# 0  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 1  ['Centrally Air Conditioned', 'Water purifier'...
# 2  ['Private Garden / Terrace', 'Water purifier',...
# 3  ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 4  ['Feng Shui / Vaastu Compliant', 'Private Gard...

# %% [markdown]
# ### property_type vs price

# %%
sns.barplot(x=df['property_type'], y=df['price'], estimator=np.median)
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'], y=df['price'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price'>

# %% [markdown]
# ### property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median)
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price_per_sqft'>

# %%
# check outliers
df[df['price_per_sqft'] > 100000][['property_type','society','sector','price','price_per_sqft','area','areaWithType']]
# Out:
#      property_type                      society     sector  price  \
# 10           house                        ansal  sector 43   1.85
# 36           house                   ardee city  sector 52   5.50
# 162          house     unitech uniworld resorts  sector 33   9.50
# 208          house                  independent  sector 23   2.80
# 281          house         bhim nagar, sector 6   sector 6   0.85
# 320           flat           ambience caitriona  sector 24  14.00
# 405          house                    rk excelo  sector 12   0.60
# 571          house                  independent  sector 55   1.45
# 577          house                  independent  sector 12   3.50
# 578          house            vatika india next  sector 82   7.00
# 905          house                  independent  sector 28   4.50
# 921          house       dlf city plots phase 2  sector 25  10.00
# 1132         house                  independent  sector 17   3.50
# 1150         house                  independent   sector 4   0.60
# 1222         house                  independent  sector 57   8.00
# 2140         house         eros rosewood villas  sector 49   2.75
# 2276         house                  independent  sector 24  10.00
# 2436         house                dlf the grove  sector 54   5.70
# 2517         house       dlf city plots phase 2  sector 25  10.50
# 3127         house                  independent  sector 12   6.00
# 3141         house  unitech nirvana birch court  sector 50   7.10
# 3170         house               uppal southend  sector 49   6.75
# 3304         house                  independent  sector 54   3.75
# 3342         house     unitech uniworld resorts  sector 33  10.00
# 3371         house       emaar the palm springs  sector 54  24.00
# 3671         house           vipul tatvam villa  sector 48   7.25
# 3688         house                  independent  sector 38   8.00
# 3703         house          huda plot sector 38  sector 38   4.30
# 3708         house       unitech deerwood chase  sector 50   8.45
#
#       price_per_sqft   area                                       areaWithType
# 10          308333.0   60.0                           Plot area 60(5.57 sq.m.)
# 36          183333.0  300.0                         Plot area 300(27.87 sq.m.)
# 162         173992.0  546.0                         Plot area 546(50.73 sq.m.)
# 208         161849.0  173.0  Plot area 173(16.07 sq.m.)Built Up area: 160 s...
# 281         126865.0   67.0                           Plot area 67(6.22 sq.m.)
# 320         200000.0  700.0                   Built Up area: 700 (65.03 sq.m.)
# 405         120000.0   50.0  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...
# 571         241666.0   60.0                           Plot area 60(5.57 sq.m.)
# 577         133079.0  263.0  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...
# 578         194444.0  360.0  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...
# 905         125000.0  360.0                   Built Up area: 360 (33.45 sq.m.)
# 921         400000.0  250.0                         Plot area 250(23.23 sq.m.)
# 1132        218750.0  160.0                   Built Up area: 160 (14.86 sq.m.)
# 1150        105263.0   57.0                            Plot area 57(5.3 sq.m.)
# 1222        266666.0  300.0                         Plot area 300(27.87 sq.m.)
# 2140        178571.0  154.0  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...
# 2276        229885.0  435.0                     Carpet area: 435 (40.41 sq.m.)
# 2436        211111.0  270.0                   Built Up area: 270 (25.08 sq.m.)
# 2517        261194.0  402.0                         Plot area 402(37.35 sq.m.)
# 3127        315789.0  190.0  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...
# 3141        283333.0  251.0                          Plot area 240(22.3 sq.m.)
# 3170        290948.0  232.0                         Plot area 232(21.55 sq.m.)
# 3304        234375.0  160.0                         Plot area 160(14.86 sq.m.)
# 3342        181818.0  550.0                          Plot area 550(51.1 sq.m.)
# 3371        600000.0  400.0                         Plot area 400(37.16 sq.m.)
# 3671        201388.0  360.0                         Plot area 360(33.45 sq.m.)
# 3688        230547.0  347.0  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...
# 3703        245398.0  175.0  Plot area 163(15.14 sq.m.)Built Up area: 145 s...
# 3708        235376.0  359.0                         Plot area 359(33.35 sq.m.)

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  experion the heartsong  sector 108   1.68          8387.0
# 1          flat         emaar digihomes   sector 62   2.45         16000.0
# 2         house             independent   sector 43   5.50          2716.0
# 3         house             independent   sector 38   3.90         21242.0
# 4         house             independent   sector 27   4.25         31481.0
#
#       area                                       areaWithType  bedRoom  \
# 0   2003.0  Super Built up area 2003(186.08 sq.m.)Built Up...        3
# 1   1531.0  Built Up area: 1200 (111.48 sq.m.)Carpet area:...        2
# 2  20250.0  Plot area 215(179.77 sq.m.)Built Up area: 2850...        8
# 3   1836.0                        Plot area 204(170.57 sq.m.)        6
# 4   1350.0  Plot area 163(136.29 sq.m.)Built Up area: 161 ...        5
#
#    bathroom balcony                             additionalRoom  floorNum  \
# 0         3      3+                    servant room,study room       4.0
# 1         2       2                                 study room       7.0
# 2         7      3+  pooja room,study room,servant room,others       3.0
# 3         6      3+         pooja room,study room,servant room       3.0
# 4         5      3+                    pooja room,servant room       3.0
#
#        facing     agePossession  \
# 0        East   1 to 5 Year Old
# 1  North-East   0 to 1 Year Old
# 2        East  5 to 10 Year Old
# 3  North-East  5 to 10 Year Old
# 4        East   1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Galleria 108 Mall', 'Dwarka Expressway', 'Ce...
# 1  ['Sector 55-56 Metro Station', 'Omaxe Gurgaon ...
# 2  ['Huda city centre metro station', 'New Life C...
# 3  ['Rajiv Chowk Mosque', 'Icici bank ATM', 'Stat...
# 4  ['Dlf phase 1 metro station', 'Sector 42-43 me...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '6 Fan', '1 Exhaust Fan', '1 Ge...
# 1  ['1 Water Purifier', '2 Fan', '1 Fridge', '1 E...
# 2  ['8 Wardrobe', '10 Fan', '1 Exhaust Fan', '10 ...
# 3                                                NaN
# 4  ['10 Wardrobe', '1 Water Purifier', '7 Fan', '...
#
#                                             features
# 0  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 1  ['Centrally Air Conditioned', 'Water purifier'...
# 2  ['Private Garden / Terrace', 'Water purifier',...
# 3  ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 4  ['Feng Shui / Vaastu Compliant', 'Private Gard...

# %% [markdown]
# ## property_type vs balcony

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['balcony']))
# Out:
# <AxesSubplot:xlabel='balcony', ylabel='property_type'>

# %% [markdown]
# ## property_type vs bathroom

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bathroom']))
# Out:
# <AxesSubplot:xlabel='bathroom', ylabel='property_type'>

# %% [markdown]
# ### property_type vs bedRoom

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <AxesSubplot:xlabel='bedRoom', ylabel='property_type'>

# %%
# checking outliers
df[df['bedRoom'] >= 10]
# Out:
#      property_type                    society      sector  price  \
# 22           house                independent   sector 11   1.35
# 27           house                independent  sector 17a   3.87
# 34           house  floor wise designer kothi   sector 25  13.00
# 118          house                independent   sector 25   9.00
# 124          house                independent   sector 46   6.50
# ...            ...                        ...         ...    ...
# 3577         house                        nul   sector 28  12.50
# 3610         house     laxmi garden sector-11   sector 11   1.50
# 3619         house                independent   sector 46   6.81
# 3688         house                independent   sector 38   8.00
# 3703         house        huda plot sector 38   sector 38   4.30
#
#       price_per_sqft    area  \
# 22            3857.0  3500.0
# 27            5160.0  7500.0
# 34           48148.0  2700.0
# 118          28490.0  3159.0
# 124          27461.0  2367.0
# ...              ...     ...
# 3577         51440.0  2430.0
# 3610         12820.0  1170.0
# 3619         36911.0  1845.0
# 3688        230547.0   347.0
# 3703        245398.0   175.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 22                         Plot area 3500(325.16 sq.m.)       10         6
# 27    Plot area 1623(150.78 sq.m.)Built Up area: 750...       19        17
# 34                          Plot area 300(250.84 sq.m.)       12        16
# 118                         Plot area 351(293.48 sq.m.)       10        10
# 124                          Plot area 263(219.9 sq.m.)       12        12
# ...                                                 ...      ...       ...
# 3577                        Plot area 270(225.75 sq.m.)       16        17
# 3610                         Plot area 130(108.7 sq.m.)       12         9
# 3619                        Plot area 205(171.41 sq.m.)       12        14
# 3688  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...       10        10
# 3703  Plot area 163(15.14 sq.m.)Built Up area: 145 s...       13        13
#
#      balcony                                 additionalRoom  floorNum  \
# 22        3+                                  not available       3.0
# 27        3+                          study room,store room       5.0
# 34        3+  pooja room,study room,servant room,store room       4.0
# 118        3                                     pooja room       3.0
# 124       3+                          pooja room,study room       4.0
# ...      ...                                            ...       ...
# 3577      3+      pooja room,study room,servant room,others       4.0
# 3610       1      pooja room,study room,servant room,others       3.0
# 3619      3+                            servant room,others       NaN
# 3688      3+                                  not available       1.0
# 3703      3+                                  not available       5.0
#
#           facing    agePossession  \
# 22           NaN     10+ Year Old
# 27    North-West  1 to 5 Year Old
# 34    North-East  0 to 1 Year Old
# 118         East     10+ Year Old
# 124   North-West  1 to 5 Year Old
# ...          ...              ...
# 3577       South  1 to 5 Year Old
# 3610        East  1 to 5 Year Old
# 3619        East  0 to 1 Year Old
# 3688       North        undefined
# 3703  North-West  1 to 5 Year Old
#
#                                         nearbyLocations  \
# 22                                                  NaN
# 27    ['Iffco chowk metro station', 'Citi bank ATM',...
# 34    ['Vodafone belvedere towers metro station', 'D...
# 118   ['Vodafone belvedere towers metro station', 'D...
# 124   ['Axis bank ATM', 'State bank of india ATM', '...
# ...                                                 ...
# 3577  ['Dlf phase 1 metro station', 'Huda city centr...
# 3610  ['Hanuman Mandir', 'Sharma Hospital Gurgaon', ...
# 3619  ['Axis bank ATM', 'State bank of india ATM', '...
# 3688  ['Raja nahar singh metro station', 'Shiv Shakt...
# 3703  ['Rajiv Chowk Mosque', 'State bank of india AT...
#
#                                          furnishDetails  \
# 22                                                  NaN
# 27                                                  NaN
# 34    ['1 Water Purifier', '36 Fan', '1 Exhaust Fan'...
# 118   ['5 Wardrobe', '1 Water Purifier', '7 Fan', '1...
# 124   ['1 Water Purifier', '1 Fridge', '10 Fan', '1 ...
# ...                                                 ...
# 3577  ['20 Fan', '1 Exhaust Fan', '16 Geyser', '1 St...
# 3610  ['7 Wardrobe', '9 Fan', '1 Exhaust Fan', '2 Ge...
# 3619  ['14 Wardrobe', '15 Fan', '1 Exhaust Fan', '13...
# 3688  ['1 Wardrobe', '1 Fan', '1 Light', 'No AC', 'N...
# 3703  ['1 Water Purifier', '17 Fan', '1 Fridge', '1 ...
#
#                                                features
# 22                                                  NaN
# 27    ['False Ceiling Lighting', 'Water Storage', 'N...
# 34    ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 118   ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 124   ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# ...                                                 ...
# 3577  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 3610  ['Security / Fire Alarm', 'High Ceiling Height...
# 3619  ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 3688                                                NaN
# 3703       ['Piped-gas', 'Internet/wi-fi connectivity']
#
# [72 rows x 17 columns]

# %% [markdown]
# ## property_type vs floorNum

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='floorNum'>

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 314          house          godrej meridien  sector 106   5.60
# 726          house              greenopolis   sector 89   0.70
# 733          house         suncity township   sector 54   2.00
# 971          house   vatika the seven lamps   sector 82   1.60
# 2260         house               ninex city   sector 76   1.75
# 2411         house  indiabulls centrum park  sector 103   3.25
# 2617         house              independent   sector 92   1.80
# 2864         house           ats tourmaline  sector 109   1.87
# 3159         house      ireo victory valley   sector 67   8.00
# 3269         house           dlf the arbour   sector 63   8.50
# 3510         house      satya the hermitage  sector 103   3.15
# 3605         house              spaze privy   sector 72   3.09
# 3609         house              spaze privy   sector 72   3.10
# 3801         house        suncity avenue 76   sector 76   0.75
#
#       price_per_sqft    area  \
# 314          14000.0  4000.0
# 726           5397.0  1297.0
# 733          30968.0   646.0
# 971           6597.0  2425.0
# 2260          6250.0  2800.0
# 2411          8125.0  4000.0
# 2617          7627.0  2360.0
# 2864          8697.0  2150.0
# 3159         22222.0  3600.0
# 3269         21519.0  3950.0
# 3510          6702.0  4700.0
# 3605          6981.0  4426.0
# 3609          8486.0  3653.0
# 3801         10067.0   745.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 314                        Plot area 4000(371.61 sq.m.)        5         4
# 726                   Built Up area: 1297 (120.5 sq.m.)        2         2
# 733   Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
# 971                        Plot area 2425(225.29 sq.m.)        4         4
# 2260                   Carpet area: 2800 (260.13 sq.m.)        4         4
# 2411                       Plot area 4000(371.61 sq.m.)        4         3
# 2617                 Built Up area: 2360 (219.25 sq.m.)        4         5
# 2864                 Built Up area: 2150 (199.74 sq.m.)        3         4
# 3159                        Plot area 400(334.45 sq.m.)        6         7
# 3269                 Built Up area: 3950 (366.97 sq.m.)        4         4
# 3510                 Built Up area: 4700 (436.64 sq.m.)        4         5
# 3605  Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
# 3609                       Plot area 3653(339.37 sq.m.)        5         5
# 3801  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
#
#      balcony                                 additionalRoom  floorNum  \
# 314       3+  pooja room,study room,servant room,store room      33.0
# 726        2                                  not available      14.0
# 733        3                                   servant room      11.0
# 971       3+                                   servant room      16.0
# 2260       0                                  not available      14.0
# 2411      3+                                  not available      20.0
# 2617       0                                  not available      13.0
# 2864       0                                  not available      12.0
# 3159      3+             pooja room,study room,servant room      51.0
# 3269      3+                                  not available      27.0
# 3510       0                                  not available      12.0
# 3605      3+                                   servant room      14.0
# 3609      3+                                  not available      21.0
# 3801       2                                  not available      11.0
#
#           facing     agePossession  \
# 314   North-East   Within 6 months
# 726   North-East         undefined
# 733        North   1 to 5 Year Old
# 971        North  5 to 10 Year Old
# 2260         NaN         undefined
# 2411         NaN          Dec 2024
# 2617         NaN         undefined
# 2864         NaN         undefined
# 3159  North-East  5 to 10 Year Old
# 3269         NaN         undefined
# 3510        East         undefined
# 3605        East   1 to 5 Year Old
# 3609         NaN   1 to 5 Year Old
# 3801  North-East   Within 6 months
#
#                                         nearbyLocations  \
# 314   ['Huda metro station', 'Gurgaon Dreamz Mall', ...
# 726                                                 NaN
# 733   ['Sector 54 chowk metro station', 'Sector metr...
# 971   ['SS Omnia Mall', 'Golf Course Ext Rd', 'Knowl...
# 2260                                                NaN
# 2411  ['Gurgaon Dreamz Mall', 'HUDA Market, Sector 1...
# 2617                                                NaN
# 2864  ['Dwarka Sector 21 Metro Station', 'NeoSquare ...
# 3159  ['AIPL Joy Street Mall', 'Golf Course Extensio...
# 3269  ['Radhakrishna Shani Mandir', 'pracksht hospit...
# 3510  ['Metro Hospital, Palam Vihar', 'Huda Metro St...
# 3605                                                NaN
# 3609                                                NaN
# 3801  ['Omaxe Gurgaon Mall', 'Gurugram University', ...
#
#                                          furnishDetails  \
# 314   ['1 Wardrobe', '1 Fan', '1 Geyser', '1 Light',...
# 726   ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 733   ['1 Water Purifier', '9 Fan', '1 Fridge', '1 E...
# 971                                                 NaN
# 2260  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 2411                                                 []
# 2617  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 2864                                                NaN
# 3159  ['15 Fan', '1 Exhaust Fan', '10 Geyser', '1 St...
# 3269  ['1 Wardrobe', '1 Fan', '1 Light', 'No AC', 'N...
# 3510                                                NaN
# 3605  ['5 Wardrobe', '1 Water Purifier', '9 Fan', '1...
# 3609  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 3801                                                NaN
#
#                                                features
# 314   ['Centrally Air Conditioned', 'Water purifier'...
# 726                                                 NaN
# 733                     ['Internet/wi-fi connectivity']
# 971   ['Security / Fire Alarm', 'Maintenance Staff',...
# 2260                                                NaN
# 2411                                                NaN
# 2617                                                NaN
# 2864                                                NaN
# 3159  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3269                                                NaN
# 3510                                                NaN
# 3605  ['Swimming Pool', 'Separate entry for servant ...
# 3609                                                NaN
# 3801  ['Feng Shui / Vaastu Compliant', 'Maintenance ...

# %%
# checking for outliers
df[(df['property_type'] == 'flat') & (df['floorNum'] > 10)]
# Out:
#      property_type                        society      sector  price  \
# 6             flat                 assotech blith   sector 99   1.60
# 11            flat            ireo victory valley   sector 67   3.50
# 49            flat     ramprastha the edge towers  sector 37d   1.00
# 57            flat     central park flower valley  sohna road   1.20
# 58            flat           dlf new town heights   sector 90   1.20
# ...            ...                            ...         ...    ...
# 3771          flat  ramshanti cooperative society   sector 52   1.76
# 3772          flat                   pioneer park   sector 61   2.10
# 3773          flat                     sare homes   sector 92   1.12
# 3794          flat               dlf regency park   sector 28   1.24
# 3796          flat        sidhartha ncr one phase   sector 95   0.90
#
#       price_per_sqft    area  \
# 6             6667.0  2400.0
# 11           14583.0  2400.0
# 49            5649.0  1770.0
# 57            6742.0  1780.0
# 58            6217.0  1930.0
# ...              ...     ...
# 3771          7242.0  2430.0
# 3772         11666.0  1800.0
# 3773          5358.0  2090.0
# 3794         12400.0  1000.0
# 3796          4500.0  2000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 6                    Built Up area: 2400 (222.97 sq.m.)        3         4
# 11    Super Built up area 2698(250.65 sq.m.)Built Up...        3         4
# 49               Super Built up area 1770(164.44 sq.m.)        3         3
# 57                   Built Up area: 1780 (165.37 sq.m.)        3         3
# 58                Super Built up area 1930(179.3 sq.m.)        3         3
# ...                                                 ...      ...       ...
# 3771             Super Built up area 2430(225.75 sq.m.)        4         4
# 3772  Super Built up area 1800(167.23 sq.m.)Carpet a...        3         3
# 3773                   Carpet area: 2090 (194.17 sq.m.)        4         4
# 3794  Super Built up area 1150(106.84 sq.m.)Built Up...        2         2
# 3796                 Built Up area: 2000 (185.81 sq.m.)        3         3
#
#      balcony           additionalRoom  floorNum      facing     agePossession  \
# 6          0            not available      15.0         NaN         undefined
# 11         3  pooja room,servant room      24.0  North-East   1 to 5 Year Old
# 49        3+            not available      13.0         NaN  5 to 10 Year Old
# 57         0            not available      11.0         NaN         undefined
# 58        3+            not available      15.0       North   1 to 5 Year Old
# ...      ...                      ...       ...         ...               ...
# 3771      3+            not available      12.0         NaN   0 to 1 Year Old
# 3772       3            not available      15.0  South-East   1 to 5 Year Old
# 3773       2             servant room      12.0  North-West   1 to 5 Year Old
# 3794      3+               pooja room      19.0       South  5 to 10 Year Old
# 3796       1            not available      15.0         NaN   1 to 5 Year Old
#
#                                         nearbyLocations  \
# 6     ['Huda Metro Station (Gurugram)', 'Dwarka Expr...
# 11    ['AIPL Joy Street Mall', 'Golf Course Extensio...
# 49    ['MDS Public School', 'St Pauls School', 'Sunc...
# 57                                                  NaN
# 58    ['Manish Gallexie 91', 'NH-8 IMT Manesar', 'RH...
# ...                                                 ...
# 3771  ['Radhakrishna Shani Mandir', 'Hanuman Mandir'...
# 3772  ['Sector 55-56 Rapid Metro', 'Hong Kong Bazaar...
# 3773  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
# 3794  ['Sector 42-43 metro station', 'Dlf phase 1 me...
# 3796  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
#
#                                          furnishDetails  \
# 6     ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 11    ['8 Fan', '1 Exhaust Fan', '4 Geyser', '1 Stov...
# 49                                                   []
# 57                                                  NaN
# 58                                                  NaN
# ...                                                 ...
# 3771                                                 []
# 3772  ['3 Wardrobe', '1 Water Purifier', '4 Fan', '1...
# 3773                                                NaN
# 3794  ['2 Wardrobe', '6 Fan', '1 Exhaust Fan', '3 Ge...
# 3796  ['1 Wardrobe', '1 Fan', '1 Light', 'No AC', 'N...
#
#                                                features
# 6                                                   NaN
# 11    ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 49    ['Power Back-up', 'Intercom Facility', 'Lift(s...
# 57                                                  NaN
# 58    ['Power Back-up', 'Lift(s)', 'Swimming Pool', ...
# ...                                                 ...
# 3771                                                NaN
# 3772  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 3773  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 3794  ['Centrally Air Conditioned', 'Water purifier'...
# 3796  ['Power Back-up', 'Lift(s)', 'Swimming Pool', ...
#
# [795 rows x 17 columns]

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  experion the heartsong  sector 108   1.68          8387.0
# 1          flat         emaar digihomes   sector 62   2.45         16000.0
# 2         house             independent   sector 43   5.50          2716.0
# 3         house             independent   sector 38   3.90         21242.0
# 4         house             independent   sector 27   4.25         31481.0
#
#       area                                       areaWithType  bedRoom  \
# 0   2003.0  Super Built up area 2003(186.08 sq.m.)Built Up...        3
# 1   1531.0  Built Up area: 1200 (111.48 sq.m.)Carpet area:...        2
# 2  20250.0  Plot area 215(179.77 sq.m.)Built Up area: 2850...        8
# 3   1836.0                        Plot area 204(170.57 sq.m.)        6
# 4   1350.0  Plot area 163(136.29 sq.m.)Built Up area: 161 ...        5
#
#    bathroom balcony                             additionalRoom  floorNum  \
# 0         3      3+                    servant room,study room       4.0
# 1         2       2                                 study room       7.0
# 2         7      3+  pooja room,study room,servant room,others       3.0
# 3         6      3+         pooja room,study room,servant room       3.0
# 4         5      3+                    pooja room,servant room       3.0
#
#        facing     agePossession  \
# 0        East   1 to 5 Year Old
# 1  North-East   0 to 1 Year Old
# 2        East  5 to 10 Year Old
# 3  North-East  5 to 10 Year Old
# 4        East   1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Galleria 108 Mall', 'Dwarka Expressway', 'Ce...
# 1  ['Sector 55-56 Metro Station', 'Omaxe Gurgaon ...
# 2  ['Huda city centre metro station', 'New Life C...
# 3  ['Rajiv Chowk Mosque', 'Icici bank ATM', 'Stat...
# 4  ['Dlf phase 1 metro station', 'Sector 42-43 me...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '6 Fan', '1 Exhaust Fan', '1 Ge...
# 1  ['1 Water Purifier', '2 Fan', '1 Fridge', '1 E...
# 2  ['8 Wardrobe', '10 Fan', '1 Exhaust Fan', '10 ...
# 3                                                NaN
# 4  ['10 Wardrobe', '1 Water Purifier', '7 Fan', '...
#
#                                             features
# 0  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 1  ['Centrally Air Conditioned', 'Water purifier'...
# 2  ['Private Garden / Terrace', 'Water purifier',...
# 3  ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 4  ['Feng Shui / Vaastu Compliant', 'Private Gard...

# %% [markdown]
# ## property_type vs Facing

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['facing']))
# Out:
# <AxesSubplot:xlabel='facing', ylabel='property_type'>

# %%
# checking for outliers
df[(df['property_type'] == 'flat') & (df['facing'] == 'North-East') & (df['floorNum'] > 10)  & (df['bedRoom'] > 3)]
# Out:
#      property_type                               society       sector  price  \
# 132           flat                          tulip violet    sector 69   1.85
# 494           flat                            bptp terra   sector 37d   1.55
# 603           flat                  dlf new town heights    sector 90   1.95
# 850           flat                          tulip violet    sector 69   1.72
# 983           flat                        paras quartier  gwal pahari   7.50
# 1001          flat                    sare crescent parc    sector 92   0.92
# 1054          flat                     dlf regal gardens    sector 90   1.78
# 1136          flat                   experion windchants   sector 112   5.60
# 1244          flat               indiabulls centrum park   sector 103   2.40
# 1517          flat  shapoorji pallonji joyville gurugram   sector 102   2.40
# 1527          flat                    sare crescent parc    sector 92   0.90
# 1532          flat                           ats triumph   sector 104   2.50
# 1601          flat               la vida by tata housing   sector 113   3.35
# 1603          flat                            godrej air    sector 85   2.50
# 1611          flat                            paras dews   sector 106   1.42
# 1732          flat                          dlf the icon    sector 43   6.00
# 1900          flat                            paras dews   sector 106   1.35
# 2271          flat                     chintels paradiso   sector 109   1.97
# 2313          flat                        dlf the primus   sector 82a   3.50
# 2728          flat                  dlf new town heights    sector 90   1.90
# 2770          flat                krrish provence estate  gwal pahari   7.50
# 2883          flat                           ats triumph   sector 104   2.52
# 2920          flat                         tata primanti    sector 72   5.25
# 3181          flat                            ireo skyon    sector 60   3.60
# 3302          flat                bestech park view city    sector 48   2.65
# 3315          flat                            sobha city   sector 108   4.10
# 3332          flat                  dlf new town heights    sector 86   1.55
# 3516          flat               adani m2k oyster grande   sector 102   4.55
#
#       price_per_sqft     area  \
# 132           9203.0   2010.0
# 494           7074.0   2191.0
# 603           7150.0   2727.0
# 850           8730.0   1970.0
# 983          14018.0   5350.0
# 1001          4854.0   1895.0
# 1054          8040.0   2214.0
# 1136         11529.0   4857.0
# 1244          8347.0   2875.0
# 1517         10545.0   2276.0
# 1527          4278.0   2104.0
# 1532          7936.0   3150.0
# 1601         12444.0   2692.0
# 1603          1379.0  18129.0
# 1611          6029.0   2355.0
# 1732         26086.0   2300.0
# 1900          7297.0   1850.0
# 2271          7490.0   2630.0
# 2313         13430.0   2606.0
# 2728          6967.0   2727.0
# 2770          7500.0  10000.0
# 2883          8000.0   3150.0
# 2920         15648.0   3355.0
# 3181         12815.0   2809.0
# 3302         10323.0   2567.0
# 3315         23401.0   1752.0
# 3332          6578.0   2356.0
# 3516         10000.0   4550.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 132              Super Built up area 2010(186.74 sq.m.)        4         4
# 494   Super Built up area 2191(203.55 sq.m.)Built Up...        4         3
# 603   Super Built up area 2727(253.35 sq.m.)Carpet a...        4         4
# 850              Super Built up area 1970(183.02 sq.m.)        4         4
# 983              Super Built up area 5350(497.03 sq.m.)        4         4
# 1001  Built Up area: 1895 (176.05 sq.m.)Carpet area:...        4         5
# 1054             Super Built up area 2215(205.78 sq.m.)        4         4
# 1136  Super Built up area 4857(451.23 sq.m.)Built Up...        4         6
# 1244  Super Built up area 2875(267.1 sq.m.)Built Up ...        4         6
# 1517             Super Built up area 2162(200.86 sq.m.)        4         4
# 1527             Super Built up area 1870(173.73 sq.m.)        4         5
# 1532             Super Built up area 3150(292.64 sq.m.)        4         4
# 1601                   Carpet area: 2692 (250.09 sq.m.)        4         4
# 1603                 Carpet area: 18122 (1683.59 sq.m.)        4         5
# 1611             Super Built up area 2355(218.79 sq.m.)        4         6
# 1732                   Carpet area: 2300 (213.68 sq.m.)        4         4
# 1900  Super Built up area 2355(218.79 sq.m.)Built Up...        4         4
# 2271             Super Built up area 2630(244.33 sq.m.)        4         4
# 2313                   Carpet area: 2606 (242.11 sq.m.)        5         5
# 2728  Super Built up area 2727(253.35 sq.m.)Carpet a...        4         4
# 2770            Super Built up area 10000(929.03 sq.m.)        5         6
# 2883  Super Built up area 3150(292.64 sq.m.)Built Up...        4         4
# 2920  Super Built up area 3355(311.69 sq.m.)Built Up...        4         4
# 3181  Super Built up area 2809(260.96 sq.m.)Carpet a...        4         5
# 3302  Super Built up area 2567(238.48 sq.m.)Carpet a...        4         4
# 3315  Super Built up area 2344(217.76 sq.m.)Built Up...        4         5
# 3332  Super Built up area 2356(218.88 sq.m.)Carpet a...        4         4
# 3516  Super Built up area 4650(432 sq.m.)Built Up ar...        4         4
#
#      balcony                  additionalRoom  floorNum      facing  \
# 132        2                   not available      14.0  North-East
# 494       3+                          others      19.0  North-East
# 603       3+         servant room,store room      24.0  North-East
# 850        1                   not available      12.0  North-East
# 983       3+  pooja room,servant room,others      20.0  North-East
# 1001      3+                   not available      14.0  North-East
# 1054      3+                   not available      12.0  North-East
# 1136      3+                    servant room      15.0  North-East
# 1244      3+                    servant room      15.0  North-East
# 1517      3+                   not available      15.0  North-East
# 1527      3+             servant room,others      14.0  North-East
# 1532      3+                    servant room      14.0  North-East
# 1601      3+         study room,servant room      11.0  North-East
# 1603      3+    pooja room,study room,others      16.0  North-East
# 1611      3+                    servant room      11.0  North-East
# 1732      3+                    servant room      18.0  North-East
# 1900      3+         servant room,pooja room      18.0  North-East
# 2271       2         pooja room,servant room      11.0  North-East
# 2313      3+                      study room      14.0  North-East
# 2728      3+         servant room,store room      19.0  North-East
# 2770      3+  pooja room,servant room,others      23.0  North-East
# 2883      3+         servant room,store room      19.0  North-East
# 2920      3+                    servant room      30.0  North-East
# 3181       3                    servant room      24.0  North-East
# 3302      3+         study room,servant room      11.0  North-East
# 3315       3         study room,servant room      25.0  North-East
# 3332      3+         pooja room,servant room      12.0  North-East
# 3516      3+                   not available      11.0  North-East
#
#          agePossession                                    nearbyLocations  \
# 132    1 to 5 Year Old  ['Airia Mall Sector 68', 'Southern Peripheral ...
# 494    1 to 5 Year Old  ['Airia Mall', 'Dwarka Expressway', 'Golf Cour...
# 603    1 to 5 Year Old  ['Manish Gallexie 91', 'NH-8 IMT Manesar', 'RH...
# 850    1 to 5 Year Old  ['Airia Mall Sector 68', 'Southern Peripheral ...
# 983    0 to 1 Year Old  ['Sector 55-56 Metro Station', 'Ambience Mall'...
# 1001  5 to 10 Year Old  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
# 1054   1 to 5 Year Old  ['SS Omnia, Sector 86', 'Numberdar market, IMT...
# 1136  5 to 10 Year Old  ['Ansal Plaza', 'Dwaraka Expressway', 'First S...
# 1244   1 to 5 Year Old  ['Gurgaon Dreamz Mall', 'HUDA Market, Sector 1...
# 1517   1 to 5 Year Old  ['Khan Market', 'The Esplanade Mall', 'Dwarka ...
# 1527   1 to 5 Year Old  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
# 1532   0 to 1 Year Old  ['IFFCO Chowk Metro Station', 'The Esplanade M...
# 1601   1 to 5 Year Old  ['Dwarka Sector 21', 'Pacific D21 Mall', 'Bajg...
# 1603          Mar 2024  ['Sapphire 83 Mall', 'Sector 86 Road', 'Dwarka...
# 1611   1 to 5 Year Old  ['MG Road Metro Station', 'NeoSquare Shopping ...
# 1732      10+ Year Old  ['Sector 42-43 Rapid Metro Station', 'Ardee Ma...
# 1900   1 to 5 Year Old  ['MG Road Metro Station', 'NeoSquare Shopping ...
# 2271   1 to 5 Year Old  ['Gyaananda School', 'The NorthCap University'...
# 2313   1 to 5 Year Old  ['Sapphire 83', 'NH 48', 'Cambridge Montessori...
# 2728   1 to 5 Year Old  ['Manish Gallexie 91', 'NH-8 IMT Manesar', 'RH...
# 2770   1 to 5 Year Old  ['Tniy Toons School', 'Pathways School Gurgoan...
# 2883   1 to 5 Year Old  ['IFFCO Chowk Metro Station', 'The Esplanade M...
# 2920   0 to 1 Year Old  ['Sector 55-56 Metro Station', 'Omaxe City Cen...
# 3181   1 to 5 Year Old  ['Sector 55-56 Metro', 'Golf Course Extension'...
# 3302  5 to 10 Year Old  ['Rapid Metro Sector 56', 'Sapphire Mall', 'Om...
# 3315   0 to 1 Year Old  ['Dwarka Sector 21', 'Dwarka Expressway', 'Vas...
# 3332  5 to 10 Year Old  ['City Square', 'Vatika Town Square', 'Bharat ...
# 3516   1 to 5 Year Old  ['WTC Plaza', 'Star Mall', 'Dwarka Expy, Dhanw...
#
#                                          furnishDetails  \
# 132   ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '1 Di...
# 494   ['2 Wardrobe', '5 Fan', '1 Exhaust Fan', '3 Ge...
# 603   ['5 Fan', 'No AC', 'No Bed', 'No Chimney', 'No...
# 850   ['1 Modular Kitchen', 'No AC', 'No Bed', 'No C...
# 983   ['4 Wardrobe', '3 Fan', '1 Geyser', '1 Microwa...
# 1001  ['4 Bed', '3 Wardrobe', '6 Fan', '4 Geyser', '...
# 1054  ['6 AC', 'No Bed', 'No Chimney', 'No Curtains'...
# 1136  ['5 Wardrobe', '1 Water Purifier', '12 Fan', '...
# 1244                                                NaN
# 1517                                                 []
# 1527                                                 []
# 1532                                                NaN
# 1601  ['1 Microwave', '9 AC', '1 Chimney', '1 Modula...
# 1603  ['4 Wardrobe', '1 Water Purifier', '4 Fan', '1...
# 1611                                                 []
# 1732  ['1 Fan', '1 Exhaust Fan', '5 Geyser', '11 Lig...
# 1900  ['4 Fan', '1 Exhaust Fan', '5 Light', '5 AC', ...
# 2271  ['6 AC', '1 Chimney', '1 Modular Kitchen', 'No...
# 2313  ['7 Fan', '1 Fridge', '1 Exhaust Fan', '5 Geys...
# 2728  ['4 Wardrobe', '6 Fan', '1 Exhaust Fan', '1 Mi...
# 2770                                                NaN
# 2883  ['2 Wardrobe', '1 Stove', '12 Light', '6 AC', ...
# 2920  ['4 Wardrobe', '1 Water Purifier', '5 Fan', '1...
# 3181  ['7 Wardrobe', '1 Water Purifier', '6 Fan', '1...
# 3302  ['4 Wardrobe', '1 Water Purifier', '8 Fan', '1...
# 3315  ['1 Water Purifier', '4 Fan', '1 Dining Table'...
# 3332  ['5 Wardrobe', '6 Fan', '1 Exhaust Fan', '4 Ge...
# 3516  ['7 Wardrobe', '17 Light', '5 AC', '1 Modular ...
#
#                                                features
# 132   ['Water purifier', 'Security / Fire Alarm', 'F...
# 494   ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 603   ['Centrally Air Conditioned', 'Water purifier'...
# 850   ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 983   ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1001  ['Security / Fire Alarm', 'Lift(s)', 'Water pu...
# 1054  ['Intercom Facility', 'Lift(s)', 'No open drai...
# 1136  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1244  ['Centrally Air Conditioned', 'Water purifier'...
# 1517  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1527  ['Security / Fire Alarm', 'Lift(s)', 'Maintena...
# 1532  ['Intercom Facility', 'Lift(s)', 'Maintenance ...
# 1601  ['Water purifier', 'Centrally Air Conditioned'...
# 1603  ['Security / Fire Alarm', 'Intercom Facility',...
# 1611  ['Centrally Air Conditioned', 'Security / Fire...
# 1732  ['Water purifier', 'Centrally Air Conditioned'...
# 1900  ['Centrally Air Conditioned', 'Water purifier'...
# 2271  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2313  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2728  ['Centrally Air Conditioned', 'Water purifier'...
# 2770  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2883  ['Water purifier', 'Security / Fire Alarm', 'P...
# 2920  ['Centrally Air Conditioned', 'Water purifier'...
# 3181  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 3302  ['Centrally Air Conditioned', 'Water purifier'...
# 3315  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 3332  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 3516  ['Intercom Facility', 'Lift(s)', 'Maintenance ...

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['facing'] == 'North-East')  & (df['bedRoom'] > 3)  & (df['balcony'] == '3+')]
# Out:
#      property_type                              society      sector  price  \
# 3            house                          independent   sector 38   3.90
# 33           house                          independent   sector 24   2.75
# 34           house            floor wise designer kothi   sector 25  13.00
# 142          house                          independent   sector 55   3.10
# 162          house             unitech uniworld resorts   sector 33   9.50
# ...            ...                                  ...         ...    ...
# 3190         house  international city by sobha phase 1  sector 109   6.00
# 3227         house                          independent   sector 56   7.50
# 3267         house                   vipul tatvam villa   sector 48   7.80
# 3476         house           unitech palms south city 1   sector 41   9.35
# 3704         house                     bptp visionnaire  sector 70a   4.70
#
#       price_per_sqft    area  \
# 3            21242.0  1836.0
# 33            7666.0  3587.0
# 34           48148.0  2700.0
# 142          20026.0  1548.0
# 162         173992.0   546.0
# ...              ...     ...
# 3190         24691.0  2430.0
# 3227         23148.0  3240.0
# 3267         23148.0  3370.0
# 3476         28858.0  3240.0
# 3704         18008.0  2610.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 3                           Plot area 204(170.57 sq.m.)        6         6
# 33                   Built Up area: 3000 (278.71 sq.m.)        7         7
# 34                          Plot area 300(250.84 sq.m.)       12        16
# 142                         Plot area 172(143.81 sq.m.)        5         4
# 162                          Plot area 546(50.73 sq.m.)        6         6
# ...                                                 ...      ...       ...
# 3190                        Plot area 270(225.75 sq.m.)        4         4
# 3227                        Plot area 360(301.01 sq.m.)        8         8
# 3267                        Plot area 360(301.01 sq.m.)        4         4
# 3476  Plot area 3240(301.01 sq.m.)Built Up area: 750...       10        10
# 3704                        Plot area 290(242.48 sq.m.)        4         4
#
#      balcony                                 additionalRoom  floorNum  \
# 3         3+             pooja room,study room,servant room       3.0
# 33        3+                                         others       3.0
# 34        3+  pooja room,study room,servant room,store room       4.0
# 142       3+                        servant room,store room       2.0
# 162       3+                                  not available       3.0
# ...      ...                                            ...       ...
# 3190      3+  store room,servant room,study room,pooja room       2.0
# 3227      3+             pooja room,study room,servant room       3.0
# 3267      3+  pooja room,study room,servant room,store room       2.0
# 3476      3+                        servant room,study room       4.0
# 3704      3+                                         others       3.0
#
#           facing     agePossession  \
# 3     North-East  5 to 10 Year Old
# 33    North-East  5 to 10 Year Old
# 34    North-East   0 to 1 Year Old
# 142   North-East  5 to 10 Year Old
# 162   North-East  5 to 10 Year Old
# ...          ...               ...
# 3190  North-East   1 to 5 Year Old
# 3227  North-East   1 to 5 Year Old
# 3267  North-East   1 to 5 Year Old
# 3476  North-East  5 to 10 Year Old
# 3704  North-East   0 to 1 Year Old
#
#                                         nearbyLocations  \
# 3     ['Rajiv Chowk Mosque', 'Icici bank ATM', 'Stat...
# 33    ['Sector 53-54 metro station', 'Sector 42-43 m...
# 34    ['Vodafone belvedere towers metro station', 'D...
# 142   ['Mg road metro station', 'Iffco chowk metro s...
# 162   ['Rajiv Chowk Mosque', 'Airforce Hospital', 'S...
# ...                                                 ...
# 3190  ['Dwarka sector 21 metro station', 'Pacific D2...
# 3227  ['Sector metro station', 'Sector metro station...
# 3267  ['Athena', 'Star Mall', 'The Sixth Element Sch...
# 3476  ['Huda city centre metro station', 'Hdfc ATM',...
# 3704  ['Good Earth City Center 2', 'Kunskapsskolan I...
#
#                                          furnishDetails  \
# 3                                                   NaN
# 33    ['7 Wardrobe', '16 Fan', '16 Light', 'No AC', ...
# 34    ['1 Water Purifier', '36 Fan', '1 Exhaust Fan'...
# 142   ['4 Wardrobe', '8 Fan', '1 Exhaust Fan', '2 Ge...
# 162   ['6 Wardrobe', '14 Fan', '1 Exhaust Fan', '7 G...
# ...                                                 ...
# 3190                                                NaN
# 3227  ['1 Water Purifier', '25 Fan', '1 Fridge', '1 ...
# 3267  ['1 Water Purifier', '7 Fan', '1 Exhaust Fan',...
# 3476  ['6 Fan', '10 Light', '5 AC', '1 Modular Kitch...
# 3704  ['1 Fan', '1 Geyser', '1 Light', '1 Chimney', ...
#
#                                                features
# 3     ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 33                                                  NaN
# 34    ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 142   ['High Ceiling Height', 'False Ceiling Lightin...
# 162   ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# ...                                                 ...
# 3190  ['Centrally Air Conditioned', 'Water purifier'...
# 3227  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3267  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 3476  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3704  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
# [80 rows x 17 columns]

# %% [markdown]
# ## property_type vs agePossession

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <AxesSubplot:xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <AxesSubplot:xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# <AxesSubplot:xlabel='bedRoom', ylabel='property_type'>

# %%
# sector analysis
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <AxesSubplot:xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %% [markdown]
# ### price

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df[df['area']<10000]['area'],df['price'],hue=df['bedRoom'])
# Out:
# C:\Users\Sri Charitha Narra\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df[df['area']<10000]['area'],df['price'],hue=df['agePossession'])
# Out:
# C:\Users\Sri Charitha Narra\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df[df['area']<10000]['area'],df['price'],hue=df['facing'].astype('category'))
# Out:
# C:\Users\Sri Charitha Narra\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df[df['area']<10000]['area'],df['price'],hue=df['floorNum'].astype('category'))
# Out:
# C:\Users\Sri Charitha Narra\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
sns.barplot(x=df['bedRoom'],y=df['price'],estimator=np.median)
# Out:
# <AxesSubplot:xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['floorNum'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['facing'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### correlation

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price             1.000000
# bathroom          0.589860
# bedRoom           0.522975
# price_per_sqft    0.391273
# area              0.019645
# floorNum         -0.094160
# Name: price, dtype: float64

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  experion the heartsong  sector 108   1.68          8387.0
# 1          flat         emaar digihomes   sector 62   2.45         16000.0
# 2         house             independent   sector 43   5.50          2716.0
# 3         house             independent   sector 38   3.90         21242.0
# 4         house             independent   sector 27   4.25         31481.0
#
#       area                                       areaWithType  bedRoom  \
# 0   2003.0  Super Built up area 2003(186.08 sq.m.)Built Up...        3
# 1   1531.0  Built Up area: 1200 (111.48 sq.m.)Carpet area:...        2
# 2  20250.0  Plot area 215(179.77 sq.m.)Built Up area: 2850...        8
# 3   1836.0                        Plot area 204(170.57 sq.m.)        6
# 4   1350.0  Plot area 163(136.29 sq.m.)Built Up area: 161 ...        5
#
#    bathroom balcony                             additionalRoom  floorNum  \
# 0         3      3+                    servant room,study room       4.0
# 1         2       2                                 study room       7.0
# 2         7      3+  pooja room,study room,servant room,others       3.0
# 3         6      3+         pooja room,study room,servant room       3.0
# 4         5      3+                    pooja room,servant room       3.0
#
#        facing     agePossession  \
# 0        East   1 to 5 Year Old
# 1  North-East   0 to 1 Year Old
# 2        East  5 to 10 Year Old
# 3  North-East  5 to 10 Year Old
# 4        East   1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Galleria 108 Mall', 'Dwarka Expressway', 'Ce...
# 1  ['Sector 55-56 Metro Station', 'Omaxe Gurgaon ...
# 2  ['Huda city centre metro station', 'New Life C...
# 3  ['Rajiv Chowk Mosque', 'Icici bank ATM', 'Stat...
# 4  ['Dlf phase 1 metro station', 'Sector 42-43 me...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '6 Fan', '1 Exhaust Fan', '1 Ge...
# 1  ['1 Water Purifier', '2 Fan', '1 Fridge', '1 E...
# 2  ['8 Wardrobe', '10 Fan', '1 Exhaust Fan', '10 ...
# 3                                                NaN
# 4  ['10 Wardrobe', '1 Water Purifier', '7 Fan', '...
#
#                                             features
# 0  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 1  ['Centrally Air Conditioned', 'Water purifier'...
# 2  ['Private Garden / Terrace', 'Water purifier',...
# 3  ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 4  ['Feng Shui / Vaastu Compliant', 'Private Gard...

# %%
sns.pairplot(df)
